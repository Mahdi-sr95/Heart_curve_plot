# %%
# !pip install ipywidgets --quiet

import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact
import warnings
warnings.filterwarnings("ignore")


def plot_show(k=100):
    x_vals = np.linspace(-3, 3, 2000)
    abs_x = np.abs(x_vals)
    y_vals = abs_x**(2/3) + 0.9 * np.sin(k * x_vals) * np.sqrt(3 - abs_x)
    y_vals = np.where(abs_x <= 3, y_vals, np.nan)


    fig, ax = plt.subplots(figsize=(10, 6))
    fig.patch.set_facecolor('#001f3f')
    ax.set_facecolor('#001f3f')

    ax.plot(x_vals, y_vals, color='red', linewidth=2.5, label='plot Curve')
    ax.set_title(f'Plot | k = {k}', fontsize=14, color='white')
    ax.set_xlabel('x', color='white')
    ax.set_ylabel('f(x)', color='white')
    ax.tick_params(colors='white')
    ax.grid(True, color='gray', linestyle='--', linewidth=0.5)
    ax.legend(facecolor='#001f3f', edgecolor='white', labelcolor='white')
    plt.show()


interact(plot_show, k=(10, 110, 10))
# Out:
# interactive(children=(IntSlider(value=100, description='k', max=110, min=10, step=10), Output()), _dom_classes…
# <function __main__.plot_show(k=100)>
